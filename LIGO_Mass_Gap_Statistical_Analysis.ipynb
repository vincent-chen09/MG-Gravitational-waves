# %% [markdown]
# <a href="https://colab.research.google.com/github/vincent-chen09/MG-Gravitational-waves/blob/main/LIGO_Mass_Gap_Statistical_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import kstest, ks_2samp

# %%
#data from LIGO "Masses in the Stellar Graveyard" from Aaron Geller
mgdata = pd.DataFrame({'Effective spin':[0,0.06,0, 0.02, -0.1], 'Chirp mass': [1.186, 1.44, 6.11, 6.56, 1.94]})
bhdata = pd.DataFrame({'Effective spin':[-0.01, 0.05, 0.18, -0.04, 0.03, 0.37, 0.08, 0.07, -0.09, 0.09, 0.68, -0.03, 0.21, -0.04, -0.01, -0.1, 0.23, -0.05, 0.02, 0.16, -0.08, 0.49, 0.33, -0.14, 0.1, 0.1, 0.12, 0.34, 0.1, -0.08, 0.28, -0.4, 0.05, 0.25, 0.19, -0.04, 0.09, 0.13, 0.07, -0.01, 0.37, 0.15, 0.05, 0, -0.03, 0.2, -0.08, 0.03, 0.09, -0.02, -0.03, 0.19, 0.21, -0.02, -0.29, 0, 0.21, 0.18, 0.06, 0.05, 0.16, -0.04, 0.11, 0, -0.04, -0.05, 0.06, -0.15, 0.12, 0.11, 0.04, -0.08, 0.45, -0.12, 0.1, -0.08, 0.06, -0.07, 0.1, -0.12, 0.01, 0.32, 0.16, -0.02, 0.13, 0.27, 0.31],
                       'Chirp mass':[28.6, 15.2, 8.9, 21.4, 7.9, 35.4, 24.9, 24.1, 26.5, 29.2, 34, 18.5, 13.3, 24.5, 33.3, 31.4, 76, 29.3, 14.6, 21.8, 29.1, 26.5, 44.3, 63.3, 32.8, 23.9, 48, 38.1, 25.4, 40.2, 45.6, 8.4, 13.1, 22.8, 9, 7.4, 29.4, 8.6, 29.7, 27.6, 31.9, 24.6, 13.4, 33.5, 24.4, 26.9, 3.7, 5.8, 15.6, 24.4, 35.6, 8.5, 8.34, 7.82, 47.5, 10.7, 8.65, 29.9, 7.31, 19.8, 8.56, 18.4, 8.33, 4.31, 33.8, 36.5, 27.4, 2.43, 32, 27.2, 7.49, 27.7, 19.8, 26.7, 32.9, 27.6, 62, 28.2, 31.1, 14.2, 23.4, 17.5, 34, 26.6, 8.75, 15, 103.2] })
stat, p_value = ks_2samp(mgdata, bhdata)
print("Two-sample KS test:", stat, p_value)
# Out:
# Two-sample KS test: [0.48275862 0.95402299] [1.59209623e-01 5.12433341e-06]

# %%
import pandas as pd
import seaborn as sns
gravitational_data = pd.DataFrame({'Effective spin':[-0.01, 0.05, 0.18, -0.04, 0.03, 0.37, 0.08, 0.07, 0, -0.09, 0.09, 0.68, -0.03, 0.21, -0.04, -0.01, -0.1, 0.06, 0.23, -0.05, 0.02, 0.16, -0.08, 0.49, 0.33, -0.14, 0.1, 0.1, 0.12, 0.34, 0.1, -0.08, 0.28, -0.4, 0.05, 0.25, 0.19, -0.04, 0.09, 0.13, 0.07, -0.01, 0.37, 0, 0.15, 0.05, 0, -0.03, 0.2, -0.08, 0.03, 0.09, -0.02, -0.03, 0.19, 0.21, -0.02, -0.29, 0, 0.21, 0.18, 0.06, 0.05, 0.16, -0.04, 0.11, 0, -0.04, -0.05, 0.06, -0.15, 0.12, 0.11, 0.04, -0.08, 0.45, -0.12, 0.02, 0.1, -0.08, 0.06, -0.07, 0.1, -0.12, 0.01, 0.32, 0.16, -0.02, 0.13, 0.27, -0.1, 0.31],
                                   'Chirp mass':[28.6, 15.2, 8.9, 21.4, 7.9, 35.4, 24.9, 24.1, 1.186, 26.5, 29.2, 34, 18.5, 13.3, 24.5, 33.3, 31.4, 1.44, 76, 29.3, 14.6, 21.8, 29.1, 26.5, 44.3, 63.3, 32.8, 23.9, 48, 38.1, 25.4, 40.2, 45.6, 8.4, 13.1, 22.8, 9, 7.4, 29.4, 8.6, 29.7, 27.6, 31.9, 6.11, 24.6, 13.4, 33.5, 24.4, 26.9, 3.7, 5.8, 15.6, 24.4, 35.6, 8.5, 8.34, 7.82, 47.5, 10.7, 8.65, 29.9, 7.31, 19.8, 8.56, 18.4, 8.33, 4.31, 33.8, 36.5, 27.4, 2.43, 32, 27.2, 7.49, 27.7, 19.8, 26.7, 6.56, 32.9, 27.6, 62, 28.2, 31.1, 14.2, 23.4, 17.5, 34, 26.6, 8.75, 15, 1.94, 103.2],
                                   'Object':['BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'MG', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'MG', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'MG', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'MG', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'BH', 'MG', 'BH']})
sns.kdeplot(data =gravitational_data, x = 'Effective spin', y = 'Chirp mass',fill = True, hue = 'Object')
sns.scatterplot(data =gravitational_data, x = 'Effective spin', y = 'Chirp mass', hue = 'Object')
# Out:
# <Axes: xlabel='Effective spin', ylabel='Chirp mass'>
